# %% [markdown]
# # Modelling & solving the multiple couriers planning problem
#
# Matthieu Feraud and Marius Lesaulnier | Erasmus 2022 - 2023

# %% [markdown]
# ---

# %% [markdown]
# ## Installations and Imports

# %%
# !pip3 install z3-solver
# !pip3 install utils
# !pip3 install gurobipy
# Out:
# Collecting z3-solver
#   Downloading z3_solver-4.12.2.0-py2.py3-none-manylinux2014_x86_64.whl (55.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 MB 9.4 MB/s eta 0:00:00
# Installing collected packages: z3-solver
# Successfully installed z3-solver-4.12.2.0
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1
# Collecting gurobipy
#   Downloading gurobipy-10.0.2-cp310-cp310-manylinux2014_x86_64.whl (12.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 57.7 MB/s eta 0:00:00
# Installing collected packages: gurobipy
# Successfully installed gurobipy-10.0.2

# %%
from os import scandir
import csv
import numpy as np
from math import log2
from z3 import *
import time
import json
from math import floor
from gurobipy import Model, GRB, quicksum

# %%
filespath = 'Instances/'
data_list = []

with scandir(filespath) as file_list:
    for filename in file_list:
        with open(filespath + filename.name) as f:
            lines = f.readlines()

            num_couriers = int(lines[0].strip())
            num_items = int(lines[1].strip())
            courier_loads = [int(i) for i in lines[2].strip().split()]
            item_sizes = [int(i) for i in lines[3].strip().split()]
            distance_matrix = [[int(j) for j in i.strip().split()] for i in lines[4:]]

            data_list.append({
                "name" : filename.name[4:6],
                "m": num_couriers,
                "n": num_items,
                "l": courier_loads,
                "s": item_sizes,
                "D": distance_matrix
            })

# %%
data_list = sorted(data_list, key=lambda x: x['m'] + x['n'])
for i in range(20):
  data = data_list[i]
  m = data['m']  # num_couriers
  n = data['n']  # num_items
  print("id: "+str(i)+" m: "+str(m), "n: "+str(n), data['D'][0])
# Out:
# id: 0 m: 2 n: 3 [0, 21, 86, 99]
# id: 1 m: 2 n: 6 [0, 3, 4, 5, 6, 6, 2]
# id: 2 m: 3 n: 7 [0, 3, 3, 6, 5, 6, 6, 2]
# id: 3 m: 6 n: 8 [0, 80, 131, 22, 41, 127, 87, 48, 113]
# id: 4 m: 6 n: 9 [0, 199, 119, 28, 179, 77, 145, 61, 123, 87]
# id: 5 m: 8 n: 10 [0, 56, 86, 87, 81, 128, 107, 163, 166, 98, 93]
# id: 6 m: 8 n: 10 [0, 56, 86, 77, 81, 128, 107, 154, 70, 93, 53]
# id: 7 m: 10 n: 13 [0, 49, 80, 59, 112, 79, 112, 187, 28, 47, 36, 69, 138, 54]
# id: 8 m: 10 n: 13 [0, 21, 86, 14, 84, 72, 24, 54, 83, 70, 8, 91, 42, 57]
# id: 9 m: 6 n: 17 [0, 20, 19, 28, 58, 48, 45, 32, 90, 61, 71, 59, 65, 46, 72, 51, 46, 66]
# id: 10 m: 3 n: 47 [0, 60, 141, 22, 41, 137, 77, 48, 92, 105, 113, 103, 82, 15, 79, 24, 98, 69, 82, 30, 105, 89, 57, 94, 75, 50, 127, 16, 36, 77, 57, 70, 51, 101, 88, 38, 83, 108, 81, 124, 54, 131, 99, 70, 112, 162, 94, 64]
    x = [[Bool(f"x_{i}_{j}") for j in range(num_items+1)] for i in range(num_items+1)]
    #These variables signal ’true’ when courier k is allocated to node i
    v = [[Bool(f"v_{i}_{k}") for k in range(num_couriers)] for i in range(num_items)]

    num_bits = int(log2(num_items))+1
    #These variables purpose is to encode the sequence of node visits in binary notation
    u = [[Bool(f"u_{i}_{k}") for k in range(num_bits)] for i in range(num_items)]
    return x, v, u

# %%
def exactly_one(boolean_vars):
    return And(AtMost(*boolean_vars, 1), AtLeast(*boolean_vars, 1))

# %%
def add_constraints(solver, x, v, u, num_couriers, num_items, max_loads, item_sizes, distance_matrix, max_distance):
    # No route from itself to itself
    solver.add([x[i][i] == False for i in range(num_items+1)])

    # Each location must be visited exactly once
    for i in range(num_items):
        solver.add(exactly_one([x[i][j] for j in range(num_items+1)]))
        solver.add(exactly_one([x[j][i] for j in range(num_items+1)]))

    # At most num_couriers couriers can start from the origin and return to the origin
    solver.add((Sum([x[num_items][j] for j in range(num_items)])== num_couriers))
    solver.add((Sum([x[i][num_items] for i in range(num_items)])== num_couriers))

    solver.add([[x[j][i] == False for i in range(num_items)] for j in range(num_items) if i < j and distance_matrix[i,j] == distance_matrix[j,i] ])

    # If courier i goes from location j to location k, then courier i must also carry item j
    solver.add([Implies(x[i][j], v[i][k] == v[j][k]) for k in range(num_couriers) for i in range(num_items) for j in range(num_items)])

    # Each item must be carried by exactly one courier
    for i in range(num_items):
        solver.add(exactly_one([v[i][k] for k in range(num_couriers)]))

    # The total size of items carried by each courier must not exceed the courier's max load
    # PbLe to restrict the weighted sum of each items of each couriers to be less or equal to their max_loads
    for k in range(num_couriers):
        solver.add(PbLe([(v[i][k], item_sizes[i]) for i in range(num_items)], max_loads[k]))

    # The total distance travelled by the couriers must not exceed the max distance
    solver.add(PbLe([(x[i][j], distance_matrix[i, j]) for j in range(num_items+1) for i in range(num_items+1) if i!=j], max_distance-1))

    # Symmetry-breaking constraint: If courier i goes from the origin to location j, then i must be less than j, order of node assignment
    #solver.add([Implies(And(x[num_items][i],x[i][j]),i<j) for i in range(num_items) for j in range(num_items) if i!=j])

    # Each courier must carry at least one item
    solver.add([AtLeast(*[v[i][k] for i in range(num_items)], 1) for k in range(num_couriers)])

# %% [markdown]
# ### Formulating the Optimization Problem

# %%
def define_problem(num_couriers, num_items, max_loads, item_sizes, distance_matrix, max_distance=None):
    distance_matrix = np.array(distance_matrix)

    if max_distance is None:
        max_distance = int(np.sum(distance_matrix))

    solver = SolverFor("QF_BV")

    x, v, u = define_decision_variables(num_couriers, num_items)

    print(max_distance)
    add_constraints(solver, x, v, u, num_couriers, num_items, max_loads, item_sizes, distance_matrix, max_distance)

    #total_distance = Sum([distance_matrix[i, j] * x[i][j] for j in range(num_items + 1) for i in range(num_items + 1) if i != j])
    #solver.minimize(total_distance)
    return solver, x, v

# %% [markdown]
# ### Interpreting and Displaying Optimization Results

# %%
def handle_solution(solver, x, v, num_couriers, num_items, distance_matrix):
    solver.set("timeout", 60)  # timeout is in milliseconds
    model = solver.model()
    route_matrix = [[model.evaluate(x[i][j]) for j in range(num_items + 1)] for i in range(num_items + 1)]
    item_courier_matrix = [[model.evaluate(v[i][k]) for k in range(num_couriers)] for i in range(num_items)]

    num_nodes = len(route_matrix) - 1
    routes = {}
    courier_distance = {}

    for k in range(num_couriers):
      id_items_to_transport = []
      for i in range(num_items):
          if item_courier_matrix[i][k]:
              id_items_to_transport.append(i+1)

      courier_path = []
      courier_total_distance = 0
      current_node = num_nodes

      courier_path.append(0)

      for item in id_items_to_transport:
          next_node = item - 1
          courier_path.append(next_node+1)
          courier_total_distance += distance_matrix[current_node][next_node]
          current_node = next_node

      courier_path.append(0)

      # Calculate the distance from the last node to the origin node
      courier_total_distance += distance_matrix[current_node][0]
      if len(courier_path)>2:
        routes[k+1] = courier_path
        courier_distance[k+1] = courier_total_distance

    total_distance=0

    # Print the courier paths and distances
    print("Courier Paths:")
    print("-" * 60)
    print("{:<10s} {:<30s} {:<15s}".format("Courier", "Path", "Distance"))
    print("-" * 60)
    for courier_id, route in routes.items():
        path_display = " > ".join([str(node) for node in route])
        distance_display = f"{courier_distance[courier_id]:,}"
        total_distance += courier_distance[courier_id]

        print("{:<10d} {:<30s} {:<15s}".format(courier_id, path_display, distance_display))
    print("-" * 60)

    print("Total distance:", f"{total_distance:,}")
    return total_distance, routes

# %% [markdown]
# ### Executing Item Assignment and Route Optimization for the SAT Model

# %%
def assign(num_couriers, num_items, max_loads, item_sizes, distance_matrix,name):
    if sum(item_sizes) > sum(max_loads):
        print("Total weight of all items surpasses possible weight transportable")
        return 0

    remaining_time = 300
    solver, x, v = define_problem(num_couriers, num_items, max_loads, item_sizes, distance_matrix)
    time_before = time.time()

    last_obj = 0

    path_res = "res/SAT/"
    if solver.check() == sat:
        total_distance, courier_path = handle_solution(solver, x, v, num_couriers, num_items, distance_matrix)
        elapsed_time = time.time()-time_before



        remaining_time -= elapsed_time
        print(f"Initial solution found with total distance: {total_distance}")

        while remaining_time > 0:
            print(f"Looking for solutions with total distance < {total_distance}")
            time_before = time.time()
            solver, x, v = define_problem(num_couriers, num_items, max_loads, item_sizes, distance_matrix, total_distance)

            if solver.check() == sat:
                total_distance, courier_path = handle_solution(solver, x, v, num_couriers, num_items, distance_matrix)
                elapsed_time = time.time()-time_before
                remaining_time -= elapsed_time

                out = {}
                out["time"] = floor(300 - remaining_time)
                out["obj"] = total_distance

                print(courier_path)

                total_path = []

                for _ , r in courier_path.items():
                  l = [i for i in list(r) if i != 0]
                  print(l)
                  total_path.append(l)
                out["sol"] = total_path
                with open(path_res + name+ ".txt", 'w') as f:
                  json.dump(out, f, ensure_ascii=False, indent=4)

                if last_obj >= total_distance:
                  return 0

                last_obj = total_distance


                print(f"Elapsed time: {elapsed_time:.2f} seconds")
                print(f"Remaining time: {remaining_time:.2f} seconds")
            else:
                print("No more solutions found.")
                break

        if remaining_time <= 0:
            print("Time limit exceeded")
        return 0
    else:
        print("Failed to find a solution")
        return 0

# %%
for i in range(20):

  data = data_list[i]
  m = data['m']  # num_couriers
  n = data['n']  # num_items
  l = data['l']  # courier_loads
  s = data['s']  # item_sizes
  D = data['D']  # distance_matrix
  name = data['name']

  assign(m,n,l,s,D,name)
# Out:
# 802
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 2 > 0                      101
# 2          0 > 1 > 3 > 0                  237
# ------------------------------------------------------------
# Total distance: 338
# Initial solution found with total distance: 338
# Looking for solutions with total distance < 338
# 338
# No more solutions found.
# 176
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 3 > 4 > 5 > 0              18
# 2          0 > 1 > 2 > 6 > 0              18
# ------------------------------------------------------------
# Total distance: 36
# Initial solution found with total distance: 36
# Looking for solutions with total distance < 36
# 36
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 3 > 4 > 5 > 0              18
# 2          0 > 1 > 2 > 6 > 0              18
# ------------------------------------------------------------
# Total distance: 36
# {1: [0, 3, 4, 5, 0], 2: [0, 1, 2, 6, 0]}
# [3, 4, 5]
# [1, 2, 6]
# Elapsed time: 0.04 seconds
# Remaining time: 299.94 seconds
# Looking for solutions with total distance < 36
# 36
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 3 > 4 > 5 > 0              18
# 2          0 > 1 > 2 > 6 > 0              18
# ------------------------------------------------------------
# Total distance: 36
# {1: [0, 3, 4, 5, 0], 2: [0, 1, 2, 6, 0]}
# [3, 4, 5]
# [1, 2, 6]
# 247
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 2 > 4 > 5 > 0              16
# 2          0 > 3 > 6 > 0                  12
# 3          0 > 1 > 7 > 0                  14
# ------------------------------------------------------------
# Total distance: 42
# Initial solution found with total distance: 42
# Looking for solutions with total distance < 42
# 42
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 3 > 5 > 7 > 0              18
# 2          0 > 2 > 4 > 0                  12
# 3          0 > 1 > 6 > 0                  14
# ------------------------------------------------------------
# Total distance: 44
# {1: [0, 3, 5, 7, 0], 2: [0, 2, 4, 0], 3: [0, 1, 6, 0]}
# [3, 5, 7]
# [2, 4]
# [1, 6]
# Elapsed time: 0.05 seconds
# Remaining time: 299.93 seconds
# Looking for solutions with total distance < 44
# 44
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 3 > 5 > 7 > 0              18
# 2          0 > 2 > 4 > 0                  12
# 3          0 > 1 > 6 > 0                  14
# ------------------------------------------------------------
# Total distance: 44
# {1: [0, 3, 5, 7, 0], 2: [0, 2, 4, 0], 3: [0, 1, 6, 0]}
# [3, 5, 7]
# [2, 4]
# [1, 6]
# 6573
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 7 > 0                      113
# 2          0 > 2 > 6 > 0                  275
# 3          0 > 5 > 0                      195
# 4          0 > 4 > 0                      123
# 5          0 > 1 > 0                      113
# 6          0 > 3 > 8 > 0                  265
# ------------------------------------------------------------
# Total distance: 1,084
# Initial solution found with total distance: 1084
# Looking for solutions with total distance < 1084
# 1084
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 1 > 0                      113
# 2          0 > 6 > 0                      161
# 3          0 > 2 > 0                      117
# 4          0 > 4 > 5 > 0                  197
# 5          0 > 7 > 0                      113
# 6          0 > 3 > 8 > 0                  265
# ------------------------------------------------------------
# Total distance: 966
# {1: [0, 1, 0], 2: [0, 6, 0], 3: [0, 2, 0], 4: [0, 4, 5, 0], 5: [0, 7, 0], 6: [0, 3, 8, 0]}
# [1]
# [6]
# [2]
# [4, 5]
# [7]
# [3, 8]
# Elapsed time: 0.09 seconds
# Remaining time: 299.88 seconds
# Looking for solutions with total distance < 966
# 966
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 2 > 0                      117
# 2          0 > 3 > 0                      169
# 3          0 > 6 > 8 > 0                  257
# 4          0 > 5 > 0                      195
# 5          0 > 7 > 0                      113
# 6          0 > 1 > 4 > 0                  157
# ------------------------------------------------------------
# Total distance: 1,008
# {1: [0, 2, 0], 2: [0, 3, 0], 3: [0, 6, 8, 0], 4: [0, 5, 0], 5: [0, 7, 0], 6: [0, 1, 4, 0]}
# [2]
# [3]
# [6, 8]
# [5]
# [7]
# [1, 4]
# Elapsed time: 0.11 seconds
# Remaining time: 299.77 seconds
# Looking for solutions with total distance < 1008
# 1008
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 1 > 0                      113
# 2          0 > 6 > 0                      161
# 3          0 > 2 > 0                      117
# 4          0 > 4 > 5 > 0                  197
# 5          0 > 7 > 0                      113
# 6          0 > 3 > 8 > 0                  265
# ------------------------------------------------------------
# Total distance: 966
# {1: [0, 1, 0], 2: [0, 6, 0], 3: [0, 2, 0], 4: [0, 4, 5, 0], 5: [0, 7, 0], 6: [0, 3, 8, 0]}
# [1]
# [6]
# [2]
# [4, 5]
# [7]
# [3, 8]
# 8486
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 6 > 0                      173
# 2          0 > 1 > 3 > 5 > 7 > 0          478
# 3          0 > 4 > 0                      122
# 4          0 > 8 > 0                      148
# 5          0 > 2 > 0                      312
# 6          0 > 9 > 0                      189
# ------------------------------------------------------------
# Total distance: 1,422
# Initial solution found with total distance: 1422
# Looking for solutions with total distance < 1422
# 1422
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 6 > 0                      173
# 2          0 > 1 > 3 > 5 > 7 > 0          478
# 3          0 > 2 > 0                      312
# 4          0 > 8 > 0                      148
# 5          0 > 4 > 0                      122
# 6          0 > 9 > 0                      189
# ------------------------------------------------------------
# Total distance: 1,422
# {1: [0, 6, 0], 2: [0, 1, 3, 5, 7, 0], 3: [0, 2, 0], 4: [0, 8, 0], 5: [0, 4, 0], 6: [0, 9, 0]}
# [6]
# [1, 3, 5, 7]
# [2]
# [8]
# [4]
# [9]
# Elapsed time: 0.12 seconds
# Remaining time: 299.86 seconds
# Looking for solutions with total distance < 1422
# 1422
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 6 > 0                      173
# 2          0 > 1 > 3 > 5 > 7 > 0          478
# 3          0 > 2 > 0                      312
# 4          0 > 8 > 0                      148
# 5          0 > 4 > 0                      122
# 6          0 > 9 > 0                      189
# ------------------------------------------------------------
# Total distance: 1,422
# {1: [0, 6, 0], 2: [0, 1, 3, 5, 7, 0], 3: [0, 2, 0], 4: [0, 8, 0], 5: [0, 4, 0], 6: [0, 9, 0]}
# [6]
# [1, 3, 5, 7]
# [2]
# [8]
# [4]
# [9]
# 8432
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 6 > 0                      204
# 2          0 > 7 > 0                      158
# 3          0 > 1 > 4 > 5 > 0              354
# 4          0 > 3 > 0                      156
# 5          0 > 9 > 0                      248
# 6          0 > 8 > 0                      233
# 7          0 > 2 > 0                      93
# 8          0 > 10 > 0                     163
# ------------------------------------------------------------
# Total distance: 1,609
# Initial solution found with total distance: 1609
# Looking for solutions with total distance < 1609
# 1609
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 6 > 0                      204
# 2          0 > 1 > 0                      93
# 3          0 > 2 > 8 > 9 > 0              350
# 4          0 > 7 > 0                      158
# 5          0 > 5 > 0                      134
# 6          0 > 3 > 0                      156
# 7          0 > 4 > 0                      127
# 8          0 > 10 > 0                     163
# ------------------------------------------------------------
# Total distance: 1,385
# {1: [0, 6, 0], 2: [0, 1, 0], 3: [0, 2, 8, 9, 0], 4: [0, 7, 0], 5: [0, 5, 0], 6: [0, 3, 0], 7: [0, 4, 0], 8: [0, 10, 0]}
# [6]
# [1]
# [2, 8, 9]
# [7]
# [5]
# [3]
# [4]
# [10]
# Elapsed time: 0.17 seconds
# Remaining time: 299.80 seconds
# Looking for solutions with total distance < 1385
# 1385
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 6 > 0                      204
# 2          0 > 1 > 0                      93
# 3          0 > 2 > 8 > 9 > 0              350
# 4          0 > 7 > 0                      158
# 5          0 > 5 > 0                      134
# 6          0 > 3 > 0                      156
# 7          0 > 4 > 0                      127
# 8          0 > 10 > 0                     163
# ------------------------------------------------------------
# Total distance: 1,385
# {1: [0, 6, 0], 2: [0, 1, 0], 3: [0, 2, 8, 9, 0], 4: [0, 7, 0], 5: [0, 5, 0], 6: [0, 3, 0], 7: [0, 4, 0], 8: [0, 10, 0]}
# [6]
# [1]
# [2, 8, 9]
# [7]
# [5]
# [3]
# [4]
# [10]
# 7512
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 1 > 5 > 10 > 0             279
# 2          0 > 4 > 0                      141
# 3          0 > 2 > 0                      80
# 4          0 > 8 > 0                      273
# 5          0 > 6 > 0                      203
# 6          0 > 9 > 0                      87
# 7          0 > 7 > 0                      179
# 8          0 > 3 > 0                      141
# ------------------------------------------------------------
# Total distance: 1,383
# Initial solution found with total distance: 1383
# Looking for solutions with total distance < 1383
# 1383
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 10 > 0                     133
# 2          0 > 2 > 0                      80
# 3          0 > 8 > 0                      273
# 4          0 > 7 > 0                      179
# 5          0 > 4 > 0                      141
# 6          0 > 1 > 5 > 6 > 0              309
# 7          0 > 9 > 0                      87
# 8          0 > 3 > 0                      141
# ------------------------------------------------------------
# Total distance: 1,343
# {1: [0, 10, 0], 2: [0, 2, 0], 3: [0, 8, 0], 4: [0, 7, 0], 5: [0, 4, 0], 6: [0, 1, 5, 6, 0], 7: [0, 9, 0], 8: [0, 3, 0]}
# [10]
# [2]
# [8]
# [7]
# [4]
# [1, 5, 6]
# [9]
# [3]
# Elapsed time: 0.18 seconds
# Remaining time: 299.78 seconds
# Looking for solutions with total distance < 1343
# 1343
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 10 > 0                     133
# 2          0 > 2 > 0                      80
# 3          0 > 8 > 0                      273
# 4          0 > 7 > 0                      179
# 5          0 > 4 > 0                      141
# 6          0 > 1 > 5 > 6 > 0              309
# 7          0 > 9 > 0                      87
# 8          0 > 3 > 0                      141
# ------------------------------------------------------------
# Total distance: 1,343
# {1: [0, 10, 0], 2: [0, 2, 0], 3: [0, 8, 0], 4: [0, 7, 0], 5: [0, 4, 0], 6: [0, 1, 5, 6, 0], 7: [0, 9, 0], 8: [0, 3, 0]}
# [10]
# [2]
# [8]
# [7]
# [4]
# [1, 5, 6]
# [9]
# [3]
# 19052
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 11 > 0                     119
# 2          0 > 9 > 0                      106
# 3          0 > 3 > 0                      108
# 4          0 > 2 > 0                      64
# 5          0 > 12 > 0                     92
# 6          0 > 6 > 0                      124
# 7          0 > 4 > 0                      181
# 8          0 > 5 > 0                      220
# 9          0 > 7 > 8 > 10 > 0             573
# 10         0 > 1 > 13 > 0                 330
# ------------------------------------------------------------
# Total distance: 1,917
# Initial solution found with total distance: 1917
# Looking for solutions with total distance < 1917
# 1917
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 11 > 0                     119
# 2          0 > 3 > 0                      108
# 3          0 > 5 > 10 > 0                 239
# 4          0 > 2 > 0                      64
# 5          0 > 1 > 9 > 0                  110
# 6          0 > 13 > 0                     329
# 7          0 > 7 > 0                      219
# 8          0 > 4 > 0                      181
# 9          0 > 6 > 0                      124
# 10         0 > 8 > 12 > 0                 488
# ------------------------------------------------------------
# Total distance: 1,981
# {1: [0, 11, 0], 2: [0, 3, 0], 3: [0, 5, 10, 0], 4: [0, 2, 0], 5: [0, 1, 9, 0], 6: [0, 13, 0], 7: [0, 7, 0], 8: [0, 4, 0], 9: [0, 6, 0], 10: [0, 8, 12, 0]}
# [11]
# [3]
# [5, 10]
# [2]
# [1, 9]
# [13]
# [7]
# [4]
# [6]
# [8, 12]
# Elapsed time: 0.31 seconds
# Remaining time: 299.64 seconds
# Looking for solutions with total distance < 1981
# 1981
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 11 > 0                     119
# 2          0 > 3 > 9 > 0                  160
# 3          0 > 5 > 10 > 0                 239
# 4          0 > 2 > 0                      64
# 5          0 > 1 > 0                      54
# 6          0 > 13 > 0                     329
# 7          0 > 7 > 0                      219
# 8          0 > 4 > 0                      181
# 9          0 > 6 > 0                      124
# 10         0 > 8 > 12 > 0                 488
# ------------------------------------------------------------
# Total distance: 1,977
# {1: [0, 11, 0], 2: [0, 3, 9, 0], 3: [0, 5, 10, 0], 4: [0, 2, 0], 5: [0, 1, 0], 6: [0, 13, 0], 7: [0, 7, 0], 8: [0, 4, 0], 9: [0, 6, 0], 10: [0, 8, 12, 0]}
# [11]
# [3, 9]
# [5, 10]
# [2]
# [1]
# [13]
# [7]
# [4]
# [6]
# [8, 12]
# 13766
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 1 > 0                      57
# 2          0 > 8 > 0                      171
# 3          0 > 12 > 0                     213
# 4          0 > 13 > 0                     141
# 5          0 > 2 > 0                      73
# 6          0 > 11 > 0                     57
# 7          0 > 3 > 0                      119
# 8          0 > 10 > 0                     110
# 9          0 > 9 > 0                      188
# 10         0 > 4 > 5 > 6 > 7 > 0          351
# ------------------------------------------------------------
# Total distance: 1,480
# Initial solution found with total distance: 1480
# Looking for solutions with total distance < 1480
# 1480
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 4 > 0                      85
# 2          0 > 1 > 0                      57
# 3          0 > 3 > 0                      119
# 4          0 > 5 > 0                      111
# 5          0 > 13 > 0                     141
# 6          0 > 8 > 0                      171
# 7          0 > 11 > 0                     57
# 8          0 > 2 > 0                      73
# 9          0 > 12 > 0                     213
# 10         0 > 6 > 7 > 9 > 10 > 0         426
# ------------------------------------------------------------
# Total distance: 1,453
# {1: [0, 4, 0], 2: [0, 1, 0], 3: [0, 3, 0], 4: [0, 5, 0], 5: [0, 13, 0], 6: [0, 8, 0], 7: [0, 11, 0], 8: [0, 2, 0], 9: [0, 12, 0], 10: [0, 6, 7, 9, 10, 0]}
# [4]
# [1]
# [3]
# [5]
# [13]
# [8]
# [11]
# [2]
# [12]
# [6, 7, 9, 10]
# Elapsed time: 0.34 seconds
# Remaining time: 299.60 seconds
# Looking for solutions with total distance < 1453
# 1453
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 4 > 0                      85
# 2          0 > 1 > 0                      57
# 3          0 > 3 > 0                      119
# 4          0 > 5 > 0                      111
# 5          0 > 13 > 0                     141
# 6          0 > 8 > 0                      171
# 7          0 > 11 > 0                     57
# 8          0 > 2 > 0                      73
# 9          0 > 12 > 0                     213
# 10         0 > 6 > 7 > 9 > 10 > 0         426
# ------------------------------------------------------------
# Total distance: 1,453
# {1: [0, 4, 0], 2: [0, 1, 0], 3: [0, 3, 0], 4: [0, 5, 0], 5: [0, 13, 0], 6: [0, 8, 0], 7: [0, 11, 0], 8: [0, 2, 0], 9: [0, 12, 0], 10: [0, 6, 7, 9, 10, 0]}
# [4]
# [1]
# [3]
# [5]
# [13]
# [8]
# [11]
# [2]
# [12]
# [6, 7, 9, 10]
# 15719
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 6 > 0                      119
# 2          0 > 13 > 0                     76
# 3          0 > 2 > 0                      164
# 4          0 > 7 > 0                      121
# 5          0 > 1 > 3 > 4 > 8 > 9 > 10 > 11 > 12 > 14 > 15 > 16 > 17 > 0 637
# 6          0 > 5 > 0                      137
# ------------------------------------------------------------
# Total distance: 1,254
# Initial solution found with total distance: 1254
# Looking for solutions with total distance < 1254
# 1254
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 6 > 0                      119
# 2          0 > 15 > 0                     77
# 3          0 > 13 > 0                     76
# 4          0 > 7 > 0                      121
# 5          0 > 1 > 2 > 3 > 4 > 5 > 8 > 9 > 10 > 11 > 12 > 14 > 16 > 0 699
# 6          0 > 17 > 0                     93
# ------------------------------------------------------------
# Total distance: 1,185
# {1: [0, 6, 0], 2: [0, 15, 0], 3: [0, 13, 0], 4: [0, 7, 0], 5: [0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 14, 16, 0], 6: [0, 17, 0]}
# [6]
# [15]
# [13]
# [7]
# [1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 14, 16]
# [17]
# Elapsed time: 0.34 seconds
# Remaining time: 299.61 seconds
# Looking for solutions with total distance < 1185
# 1185
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 6 > 0                      119
# 2          0 > 15 > 0                     77
# 3          0 > 13 > 0                     76
# 4          0 > 7 > 0                      121
# 5          0 > 1 > 2 > 3 > 4 > 5 > 8 > 9 > 10 > 11 > 12 > 14 > 16 > 0 699
# 6          0 > 17 > 0                     93
# ------------------------------------------------------------
# Total distance: 1,185
# {1: [0, 6, 0], 2: [0, 15, 0], 3: [0, 13, 0], 4: [0, 7, 0], 5: [0, 1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 14, 16, 0], 6: [0, 17, 0]}
# [6]
# [15]
# [13]
# [7]
# [1, 2, 3, 4, 5, 8, 9, 10, 11, 12, 14, 16]
# [17]
# 185474
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 1 > 2 > 7 > 8 > 10 > 12 > 14 > 19 > 21 > 22 > 23 > 24 > 25 > 31 > 34 > 36 > 37 > 38 > 44 > 45 > 46 > 0 1,896
# 2          0 > 3 > 5 > 9 > 11 > 13 > 15 > 17 > 18 > 28 > 29 > 32 > 35 > 39 > 40 > 41 > 42 > 0 1,494
# 3          0 > 4 > 6 > 16 > 20 > 26 > 27 > 30 > 33 > 43 > 47 > 0 1,016
# ------------------------------------------------------------
# Total distance: 4,406
# Initial solution found with total distance: 4406
# Looking for solutions with total distance < 4406
# 4406
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 >
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 18 > 0                     131
# 2          0 > 17 > 20 > 37 > 44 > 0      390
# 3          0 > 22 > 0                     129
# 4          0 > 19 > 42 > 43 > 45 > 0      452
# 5          0 > 10 > 15 > 23 > 24 > 0      286
# 6          0 > 25 > 0                     122
# 7          0 > 16 > 0                     85
# 8          0 > 14 > 0                     63
# 9          0 > 4 > 8 > 12 > 13 > 21 > 30 > 39 > 41 > 0 717
# 10         0 > 1 > 5 > 7 > 9 > 11 > 26 > 28 > 31 > 33 > 34 > 35 > 36 > 0 830
# 11         0 > 27 > 0                     195
# 12         0 > 6 > 0                      203
# 13         0 > 38 > 0                     187
# 14         0 > 40 > 0                     218
# 15         0 > 29 > 0                     134
# 16         0 > 32 > 0                     77
# 17         0 > 2 > 0                      92
# 18         0 > 46 > 0                     255
# 19         0 > 47 > 0                     160
# 20         0 > 3 > 0                      209
# ------------------------------------------------------------
# Total distance: 4,935
# {1: [0, 18, 0], 2: [0, 17, 20, 37, 44, 0], 3: [0, 22, 0], 4: [0, 19, 42, 43, 45, 0], 5: [0, 10, 15, 23, 24, 0], 6: [0, 25, 0], 7: [0, 16, 0], 8: [0, 14, 0], 9: [0, 4, 8, 12, 13, 21, 30, 39, 41, 0], 10: [0, 1, 5, 7, 9, 11, 26, 28, 31, 33, 34, 35, 36, 0], 11: [0, 27, 0], 12: [0, 6, 0], 13: [0, 38, 0], 14: [0, 40, 0], 15: [0, 29, 0], 16: [0, 32, 0], 17: [0, 2, 0], 18: [0, 46, 0], 19: [0, 47, 0], 20: [0, 3, 0]}
# [18]
# [17, 20, 37, 44]
# [22]
# [19, 42, 43, 45]
# [10, 15, 23, 24]
# [25]
# [16]
# [14]
# [4, 8, 12, 13, 21, 30, 39, 41]
# [1, 5, 7, 9, 11, 26, 28, 31, 33, 34, 35, 36]
# [27]
# [6]
# [38]
# [40]
# [29]
# [32]
# [2]
# [46]
# [47]
# [3]
# Elapsed time: 8.31 seconds
# Remaining time: 290.69 seconds
# Looking for solutions with total distance < 4935
# 4935
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 18 > 0                     131
# 2          0 > 17 > 20 > 37 > 44 > 0      390
# 3          0 > 22 > 0                     129
# 4          0 > 19 > 42 > 43 > 45 > 0      452
# 5          0 > 10 > 15 > 23 > 24 > 0      286
# 6          0 > 25 > 0                     122
# 7          0 > 16 > 0                     85
# 8          0 > 14 > 0                     63
# 9          0 > 4 > 8 > 12 > 13 > 21 > 30 > 39 > 41 > 0 717
# 10         0 > 1 > 5 > 7 > 9 > 11 > 26 > 28 > 31 > 33 > 34 > 35 > 36 > 0 830
# 11         0 > 27 > 0                     195
# 12         0 > 6 > 0                      203
# 13         0 > 38 > 0                     187
# 14         0 > 40 > 0                     218
# 15         0 > 29 > 0                     134
# 16         0 > 32 > 0                     77
# 17         0 > 2 > 0                      92
# 18         0 > 46 > 0                     255
# 19         0 > 47 > 0                     160
# 20         0 > 3 > 0                      209
# ------------------------------------------------------------
# Total distance: 4,935
# {1: [0, 18, 0], 2: [0, 17, 20, 37, 44, 0], 3: [0, 22, 0], 4: [0, 19, 42, 43, 45, 0], 5: [0, 10, 15, 23, 24, 0], 6: [0, 25, 0], 7: [0, 16, 0], 8: [0, 14, 0], 9: [0, 4, 8, 12, 13, 21, 30, 39, 41, 0], 10: [0, 1, 5, 7, 9, 11, 26, 28, 31, 33, 34, 35, 36, 0], 11: [0, 27, 0], 12: [0, 6, 0], 13: [0, 38, 0], 14: [0, 40, 0], 15: [0, 29, 0], 16: [0, 32, 0], 17: [0, 2, 0], 18: [0, 46, 0], 19: [0, 47, 0], 20: [0, 3, 0]}
# [18]
# [17, 20, 37, 44]
# [22]
# [19, 42, 43, 45]
# [10, 15, 23, 24]
# [25]
# [16]
# [14]
# [4, 8, 12, 13, 21, 30, 39, 41]
# [1, 5, 7, 9, 11, 26, 28, 31, 33, 34, 35, 36]
# [27]
# [6]
# [38]
# [40]
# [29]
# [32]
# [2]
# [46]
# [47]
# [3]
# 450534
# Courier Paths:
# ------------------------------------------------------------
# Courier    Path                           Distance
# ------------------------------------------------------------
# 1          0 > 1 > 0                      167
# 2          0 > 27 > 34 > 0                351
# 3          0 > 17 > 0                     168
# 4          0 > 4 > 6 > 20 > 58 > 59 > 60 > 61 > 62 > 63 > 0 848
# 5          0 > 3 > 5 > 29 > 48 > 0        394
# 6          0 > 22 > 0                     283
# 7          0 > 16 > 0                     329
# 8          0 > 69 > 0                     223
# 9          0 > 8 > 24 > 52 > 56 > 57 > 0  558
# 10         0 > 11 > 12 > 18 > 30 > 33 > 46 > 47 > 50 > 53 > 54 > 55 > 65 > 66 > 67 > 0 1,350
# 11         0 > 68 > 0                     168
# 12         0 > 15 > 0                     303
# 13         0 > 71 > 0                     281
# 14         0 > 70 > 0                     196
# 15         0 > 14 > 0                     181
# 16         0 > 21 > 0                     167
# 17         0 > 23 > 0                     167
# 18         0 > 64 > 0                     167
# 19         0 > 36 > 0                     239
# 20         0 > 2 > 7 > 9 > 10 > 13 > 19 > 25 > 26 > 28 > 31 > 32 > 35 > 37 > 38 > 39 > 40 > 41 > 42 > 43 > 44 > 45 > 49 > 51 > 0 1,986
# ------------------------------------------------------------
# Total distance: 8,526
# Initial solution found with total distance: 8526
# Looking for solutions with total distance < 8526
# 8526
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-38-840613391c81> in <cell line: 1>()
#       9   name = data['name']
#      10
# ---> 11   assign(m,n,l,s,D,name)
#
# <ipython-input-37-f193af395a9c> in assign(num_couriers, num_items, max_loads, item_sizes, distance_matrix, name)
#      23             print(f"Looking for solutions with total distance < {total_distance}")
#      24             time_before = time.time()
# ---> 25             solver, x, v = define_problem(num_couriers, num_items, max_loads, item_sizes, distance_matrix, total_distance)
#      26
#      27             if solver.check() == sat:
#
# <ipython-input-35-2264f98408ac> in define_problem(num_couriers, num_items, max_loads, item_sizes, distance_matrix, max_distance)
#      10
#      11     print(max_distance)
# ---> 12     add_constraints(solver, x, v, u, num_couriers, num_items, max_loads, item_sizes, distance_matrix, max_distance)
#      13
#      14     #total_distance = Sum([distance_matrix[i, j] * x[i][j] for j in range(num_items + 1) for i in range(num_items + 1) if i != j])
#
# <ipython-input-34-087b3e57ee35> in add_constraints(solver, x, v, u, num_couriers, num_items, max_loads, item_sizes, distance_matrix, max_distance)
#      33
#      34     # Each courier must carry at least one item
# ---> 35     solver.add([AtLeast(*[v[i][k] for i in range(num_items)], 1) for k in range(num_couriers)])
#      36
#
# <ipython-input-34-087b3e57ee35> in <listcomp>(.0)
#      33
#      34     # Each courier must carry at least one item
# ---> 35     solver.add([AtLeast(*[v[i][k] for i in range(num_items)], 1) for k in range(num_couriers)])
#      36
#
# /usr/local/lib/python3.10/dist-packages/z3/z3.py in AtLeast(*args)
#    9013     if z3_debug():
#    9014         _z3_assert(ctx is not None, "At least one of the arguments must be a Z3 expression")
# -> 9015     args1 = _coerce_expr_list(args[:-1], ctx)
#    9016     k = args[-1]
#    9017     _args, sz = _to_ast_array(args1)
#
# /usr/local/lib/python3.10/dist-packages/z3/z3.py in _coerce_expr_list(alist, ctx)
#    1232     if not has_expr:
#    1233         alist = [_py2expr(a, ctx) for a in alist]
# -> 1234     s = _reduce(_coerce_expr_merge, alist, None)
#    1235     return [s.cast(a) for a in alist]
#    1236
#
# /usr/local/lib/python3.10/dist-packages/z3/z3.py in _reduce(func, sequence, initial)
#    1220     result = initial
#    1221     for element in sequence:
# -> 1222         result = func(result, element)
#    1223     return result
#    1224
#
# /usr/local/lib/python3.10/dist-packages/z3/z3.py in _coerce_expr_merge(s, a)
#    1179 def _coerce_expr_merge(s, a):
#    1180     if is_expr(a):
# -> 1181         s1 = a.sort()
#    1182         if s is None:
#    1183             return s1
#
# /usr/local/lib/python3.10/dist-packages/z3/z3.py in sort(self)
#    1548
#    1549     def sort(self):
# -> 1550         return BoolSortRef(Z3_get_sort(self.ctx_ref(), self.as_ast()), self.ctx)
#    1551
#    1552     def __rmul__(self, other):
#
# /usr/local/lib/python3.10/dist-packages/z3/z3.py in __init__(self, ast, ctx)
#     346         self.ast = ast
#     347         self.ctx = _get_ctx(ctx)
# --> 348         Z3_inc_ref(self.ctx.ref(), self.as_ast())
#     349
#     350     def __del__(self):
#
# /usr/local/lib/python3.10/dist-packages/z3/z3.py in as_ast(self)
#     561
#     562     def as_ast(self):
# --> 563         return Z3_sort_to_ast(self.ctx_ref(), self.ast)
#     564
#     565     def get_id(self):
#
# /usr/local/lib/python3.10/dist-packages/z3/z3core.py in Z3_sort_to_ast(a0, a1, _elems)
#    2763
#    2764 def Z3_sort_to_ast(a0, a1, _elems=Elementaries(_lib.Z3_sort_to_ast)):
# -> 2765   r = _elems.f(a0, a1)
#    2766   _elems.Check(a0)
#    2767   return r
#
# ArgumentError: argument 2: KeyboardInterrupt:

# %% [markdown]
# ## MIP Model

# %% [markdown]
# ### Defining the constraints

# %%
# Function to add constraints to the model
def add_constraints(mdl, num_items, num_couriers, Vertices, Items, Arcs, x, l, courier_assignment, aux_vars, item_loads, max_loads):

    # Only one connection into point i
    mdl.addConstrs(quicksum(x[i,j] for j in Vertices if j != i) == 1 for i in Items)

    # Only one edge out of point i
    mdl.addConstrs(quicksum(x[i,j] for i in Vertices if i != j) == 1 for j in Items)

    # "all the courriers leave the depot
    mdl.addConstr(quicksum(x[0,j] for j in Items ) == num_couriers )

    # Same number of couriers leaving and arriving to the depot
    mdl.addConstr(quicksum(x[0,j] for j in Items ) == quicksum(x[j,0] for j in Items ))

    # Sub-tour elimination
    mdl.addConstr(l[0] == 1)
    mdl.addConstrs((l[i] + x[i,j]) <= (l[j] + num_items * (1 - x[i,j])) for i,j in Arcs if j!=0 )

    # Constraints related to courier
    for k in range(num_couriers):
        mdl.addConstrs((aux_vars[i][k] <= courier_assignment[i][k]) for i in Items)
        mdl.addConstrs((aux_vars[i][k] <= x[0,i]) for i in Items )
        mdl.addConstrs((aux_vars[i][k] >= courier_assignment[i][k] + x[0,i] - 1 ) for i in Items )
        mdl.addConstr(quicksum(aux_vars[i][k] for i in Items) <= 1 )

        # If x[i,j] = True, i,j share the same courier
        for i,j in Arcs:
            if i!=0 and j!=0:
                mdl.addConstr(x[i,j] + courier_assignment[i][k] - courier_assignment[j][k] <= 1 )
                mdl.addConstr(x[i,j] - courier_assignment[i][k] + courier_assignment[j][k] <= 1 )

    # Every item should be visited by exactly one courier
    mdl.addConstrs(quicksum(courier_assignment[i][k] for k in range(num_couriers)) == 1 for i in Items)

    # The total load of items served by each courier cannot exceed the courier's capacity
    mdl.addConstrs(quicksum( item_loads[i-1] * courier_assignment[i][k] for i in Items) <= max_loads[k] for k in range(num_couriers))

# %% [markdown]
# ### Creating the model

# %%
# Function to create the Gurobi model
def create_model(num_items, num_couriers, item_loads, item_sizes, distance_matrix):

    Items = [i for i in range(1,num_items+1)]
    # Define the set of vertices, including the depot
    Vertices = [0] + Items
    Arcs = [(i, j) for i in Vertices for j in Vertices if i != j]

    Couriers_encoding = [i for i in range(num_couriers)]
    courier_assignment = {}
    aux_vars = {}

    mdl = Model('VRP')

    # Define variables
    x = mdl.addVars(Arcs, vtype=GRB.BINARY)
    l = mdl.addVars(Vertices, lb=0, ub=num_items, vtype=GRB.INTEGER)
    for i in range(1,num_items+1):
        courier_assignment[i] = mdl.addVars(Couriers_encoding, vtype=GRB.BINARY)
        aux_vars[i] = mdl.addVars(Couriers_encoding, vtype=GRB.INTEGER)

    # Objective function
    mdl.modelSense = GRB.MINIMIZE
    mdl.setObjective(quicksum(x[i, j] * distance_matrix[i, j] for (i, j) in Arcs))

    # Constraints
    add_constraints(mdl, num_items, num_couriers, Vertices, Items, Arcs, x, l, courier_assignment, aux_vars, item_loads, item_sizes)

    # Solver settings
    mdl.Params.TimeLimit = 300

    return mdl, x, courier_assignment, Items, Vertices

# %% [markdown]
# ### Displaying the Optimization Results

# %%
def handle_solution(mdl, x, courier_assignment, Items, Vertices, num_couriers):
    tours = {}
    for i in Items:
        try:
            x[(0, i)].x > 0.1
        except AttributeError:
            print("Total distance: N/A")
            break
        if x[(0, i)].x > 0.9:
            for k in range(num_couriers):
                if int(str(courier_assignment[i][k])[-6:-4]) > 0:
                    temp = k
            temp += 1
            tours[temp] = []
            path = [0, i]
            while i != 0:
                j = i
                for k in Vertices:
                    if j != k and x[(j, k)].x > 0.9:
                        path.append(k)
                        i = k
            tours[temp].append(path)

    sols = []
    for key in tours.keys():
        sol = []
        path_str = str(tours[key])
        path_str = path_str.replace("[", "")
        path_str = path_str.replace("]", "")
        path_str = path_str.replace(", ", " > ")
        tours[key] = path_str

        for i in tours[key]:
            if i != '0' and i != '>' and i != ' ':
                sol.append(int(i))
        sols.append(sol)

    tour_ids = [i for i in tours.keys()]
    print("Planned Tours:")

    for tour_id in sorted(tour_ids):
        print("Tour " + str(tour_id) + ":")
        print(tours[tour_id])

    print("---------------------------")
    try:
        print("Total distance:", int(mdl.ObjVal))
    except OverflowError:
        print("Total distance: N/A")

    return int(mdl.ObjVal), sols

# %% [markdown]
# ### Executing Item Assignment and Route Optimization for the MIP Model

# %%
def assign(num_items, num_couriers, item_loads, max_loads, distance_matrix):

    # Create distance matrix
    Dist = np.array(distance_matrix)

    # Create Gurobi model
    mdl, x, courier_assignment, Items, Vertices = create_model(num_items, num_couriers, item_loads, max_loads, Dist)

    # Optimize model
    mdl.optimize()

    # Print solution
    obj , sols = handle_solution(mdl, x, courier_assignment, Items, Vertices, num_couriers)

    return obj, sols


# assign(n, m, s, l, D)

# %%
path_res = "res/MIP/"

for i in range(5):
    print("-" * 5 + str(i) + "-" * 5)
    data = data_list[i]
    m = data['m']  # num_couriers
    n = data['n']  # num_items
    l = data['l']  # courier_loads
    s = data['s']  # item_sizes
    D = data['D']  # distance_matrix

    out = {}
    data_name = "0" + str(i + 1) if i < 10 else str(i + 1)

    time_before = time.time()
    obj, tours = assign(n, m, s, l, D)
    out["time"] = floor((time.time() - time_before) / 1000)
    out["obj"] = obj
    out["sol"] = tours

    with open(path_res + data_name + ".txt", 'w') as f:
        json.dump(out, f, ensure_ascii=False, indent=4)
# Out:
# -----0-----
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 67 rows, 28 columns and 187 nonzeros
# Model fingerprint: 0xf768cb0c
# Variable types: 0 continuous, 28 integer (18 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 3e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 338.0000000
# Presolve removed 67 rows and 28 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 338
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.380000000000e+02, best bound 3.380000000000e+02, gap 0.0000%
# Planned Tours:
# Tour 1:
# 0 > 2 > 0
# Tour 2:
# 0 > 1 > 3 > 0
# ---------------------------
# Total distance: 338
# -----1-----
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 217 rows, 73 columns and 679 nonzeros
# Model fingerprint: 0xc676ce3b
# Variable types: 0 continuous, 73 integer (54 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e+00, 8e+00]
#   Bounds range     [1e+00, 6e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 69 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 148 rows, 66 columns, 468 nonzeros
# Variable types: 0 continuous, 66 integer (60 binary)
# Found heuristic solution: objective 32.0000000
#
# Root relaxation: objective 1.928571e+01, 29 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   19.28571    0   21   32.00000   19.28571  39.7%     -    0s
# H    0     0                      27.0000000   19.28571  28.6%     -    0s
# H    0     0                      26.0000000   19.28571  25.8%     -    0s
#      0     0   20.00000    0    8   26.00000   20.00000  23.1%     -    0s
#      0     0   20.10526    0   28   26.00000   20.10526  22.7%     -    0s
#      0     0   20.75000    0   25   26.00000   20.75000  20.2%     -    0s
#      0     0   20.75000    0   25   26.00000   20.75000  20.2%     -    0s
#      0     0   22.00000    0   30   26.00000   22.00000  15.4%     -    0s
#      0     0   22.66667    0   29   26.00000   22.66667  12.8%     -    0s
#      0     0   22.66667    0   30   26.00000   22.66667  12.8%     -    0s
#      0     0   23.00000    0   14   26.00000   23.00000  11.5%     -    0s
#      0     0   23.00000    0   13   26.00000   23.00000  11.5%     -    0s
#      0     0   23.09091    0   30   26.00000   23.09091  11.2%     -    0s
# H    0     0                      25.0000000   23.09091  7.64%     -    0s
#      0     0   23.09091    0   29   25.00000   23.09091  7.64%     -    0s
#      0     0   23.09091    0   32   25.00000   23.09091  7.64%     -    0s
#      0     0   23.09091    0   33   25.00000   23.09091  7.64%     -    0s
#      0     0   23.09091    0   25   25.00000   23.09091  7.64%     -    0s
#      0     0   23.09091    0   25   25.00000   23.09091  7.64%     -    0s
#      0     2   23.66667    0   25   25.00000   23.66667  5.33%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 2
#   Implied bound: 8
#   MIR: 6
#   StrongCG: 1
#   Zero half: 1
#   RLT: 3
#   Relax-and-lift: 2
#
# Explored 17 nodes (491 simplex iterations) in 0.22 seconds (0.02 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 25 26 27 32
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.500000000000e+01, best bound 2.500000000000e+01, gap 0.0000%
# Planned Tours:
# Tour 1:
# 0 > 4 > 5 > 3 > 0
# Tour 2:
# 0 > 2 > 1 > 6 > 0
# ---------------------------
# Total distance: 25
# -----2-----
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 394 rows, 106 columns and 1233 nonzeros
# Model fingerprint: 0x0376e73f
# Variable types: 0 continuous, 106 integer (77 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+00]
#   Objective range  [2e+00, 7e+00]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [1e+00, 2e+01]
# Presolve removed 60 rows and 5 columns
# Presolve time: 0.03s
# Presolved: 334 rows, 101 columns, 1047 nonzeros
# Variable types: 0 continuous, 101 integer (94 binary)
# Found heuristic solution: objective 44.0000000
#
# Root relaxation: objective 2.971429e+01, 113 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   29.71429    0   34   44.00000   29.71429  32.5%     -    0s
#      0     0   32.57692    0   50   44.00000   32.57692  26.0%     -    0s
# H    0     0                      40.0000000   32.57692  18.6%     -    0s
#      0     0   33.00000    0   33   40.00000   33.00000  17.5%     -    0s
#      0     0   33.17241    0   50   40.00000   33.17241  17.1%     -    0s
#      0     0   33.25000    0   48   40.00000   33.25000  16.9%     -    0s
#      0     0   33.26154    0   49   40.00000   33.26154  16.8%     -    0s
#      0     0   35.08333    0   56   40.00000   35.08333  12.3%     -    0s
#      0     0   35.26667    0   57   40.00000   35.26667  11.8%     -    0s
#      0     0   35.75410    0   56   40.00000   35.75410  10.6%     -    0s
#      0     0   36.50000    0   36   40.00000   36.50000  8.75%     -    0s
#      0     0   37.41667    0   52   40.00000   37.41667  6.46%     -    0s
#      0     0   37.50000    0   46   40.00000   37.50000  6.25%     -    0s
#      0     0   37.50000    0   47   40.00000   37.50000  6.25%     -    0s
#      0     0   38.13636    0   51   40.00000   38.13636  4.66%     -    0s
#
# Cutting planes:
#   Learned: 3
#   Gomory: 1
#   Cover: 2
#   Implied bound: 12
#   Clique: 3
#   MIR: 3
#   StrongCG: 1
#   GUB cover: 1
#   Zero half: 3
#   RLT: 9
#   BQP: 2
#
# Explored 1 nodes (390 simplex iterations) in 0.23 seconds (0.04 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 40 44
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+01, best bound 4.000000000000e+01, gap 0.0000%
# Planned Tours:
# Tour 1:
# 0 > 4 > 5 > 2 > 0
# Tour 2:
# 0 > 6 > 3 > 0
# Tour 3:
# 0 > 7 > 1 > 0
# ---------------------------
# Total distance: 40
# -----3-----
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 919 rows, 177 columns and 2841 nonzeros
# Model fingerprint: 0x0a2a9353
# Variable types: 0 continuous, 177 integer (120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [4e+00, 2e+02]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [1e+00, 3e+02]
# Found heuristic solution: objective 1194.0000000
# Presolve removed 5 rows and 1 columns
# Presolve time: 0.02s
# Presolved: 914 rows, 176 columns, 2792 nonzeros
# Variable types: 0 continuous, 176 integer (168 binary)
#
# Root relaxation: objective 7.684444e+02, 98 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  768.44444    0   11 1194.00000  768.44444  35.6%     -    0s
# H    0     0                    1000.0000000  768.44444  23.2%     -    0s
# H    0     0                     860.0000000  768.44444  10.6%     -    0s
# *    0     0               0     798.0000000  798.00000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 7
#   Implied bound: 1
#   MIR: 2
#   RLT: 1
#
# Explored 1 nodes (158 simplex iterations) in 0.11 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 798 860 1000 1194
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.980000000000e+02, best bound 7.980000000000e+02, gap 0.0000%
# Planned Tours:
# Tour 1:
# 0 > 3 > 0
# Tour 2:
# 0 > 7 > 0
# Tour 3:
# 0 > 4 > 0
# Tour 4:
# 0 > 1 > 0
# Tour 5:
# 0 > 6 > 0
# Tour 6:
# 0 > 5 > 2 > 8 > 0
# ---------------------------
# Total distance: 798
# -----4-----
# Set parameter TimeLimit to value 300
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (linux64)
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1149 rows, 208 columns and 3565 nonzeros
# Model fingerprint: 0x3e93d6e2
# Variable types: 0 continuous, 208 integer (144 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [2e+01, 2e+02]
#   Bounds range     [1e+00, 9e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 7 rows and 1 columns
# Presolve time: 0.02s
# Presolved: 1142 rows, 207 columns, 3492 nonzeros
# Variable types: 0 continuous, 207 integer (198 binary)
# Found heuristic solution: objective 1161.0000000
#
# Root relaxation: objective 1.122600e+03, 95 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1122.60000    0   13 1161.00000 1122.60000  3.31%     -    0s
#      0     0 1124.60000    0   13 1161.00000 1124.60000  3.14%     -    0s
# H    0     0                    1159.0000000 1124.60000  2.97%     -    0s
# *    0     0               0    1151.0000000 1151.00000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#
# Explored 1 nodes (139 simplex iterations) in 0.10 seconds (0.02 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 1151 1159 1161
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.151000000000e+03, best bound 1.151000000000e+03, gap 0.0000%
# Planned Tours:
# Tour 1:
# 0 > 2 > 0
# Tour 2:
# 0 > 9 > 0
# Tour 3:
# 0 > 5 > 0
# Tour 4:
# 0 > 3 > 0
# Tour 5:
# 0 > 7 > 0
# Tour 6:
# 0 > 6 > 1 > 4 > 8 > 0
# ---------------------------
# Total distance: 1151
